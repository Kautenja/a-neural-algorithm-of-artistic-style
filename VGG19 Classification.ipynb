# %%
from keras.applications.imagenet_utils import decode_predictions
from neural_stylization.vgg19 import VGG_19
from neural_stylization._img_util import load_image, image_to_matrix
# Out:
# c:\users\ck\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # VGG19 Model

# %%
model = VGG_19()
model
# Out:
# VGG_19(include_top=True, input_tensor=None, pooling=max)

# %%
model.count_params()
# Out:
# 143667240

# %% [markdown]
# ## Dog

# %%
d=224
dog = load_image('img/objects/labrador-retriever.jpg', (d, d))
dog
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1DBC0C40F60>

# %%
img = image_to_matrix(dog)
img
# Out:
# array([[[[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]],
#
#         [[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]],
#
#         [[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]],
#
#         ...,
#
#         [[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]],
#
#         [[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]],
#
#         [[151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          ...,
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ],
#          [151.061  , 138.22101, 131.32   ]]]], dtype=float32)

# %%
preds = model.predict(img)
# preds

# %%
decode_predictions(preds, top=3)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.49550182),
#   ('n02099601', 'golden_retriever', 0.39968422),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.014810321)]]

# %% [markdown]
# ## Seahorse

# %%
d=224
seahorse = load_image('img/objects/seahorse.jpg', (d, d))
seahorse
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1DD692FBD30>

# %%
img = image_to_matrix(seahorse)
preds = model.predict(img)
decode_predictions(preds, top=3)
# Out:
# [[('n01694178', 'African_chameleon', 0.73380846),
#   ('n02317335', 'starfish', 0.116074696),
#   ('n01675722', 'banded_gecko', 0.055367026)]]
