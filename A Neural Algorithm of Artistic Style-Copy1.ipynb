# %%
from neural_stylization.neural_alg_of_artistic_style import Canvas, NeuralAlgorithmOfArtisticStyle
# Out:
# c:\users\ck\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
canvas = Canvas(content_path='img/content/unfinished_business.jpg',
                style_path='img/styles/rick_and_morty.png')
canvas
# Out:
# Canvas(content_path='img/content/unfinished_business.jpg', style_path='img/styles/rick_and_morty.png')

# %%
canvas.content_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x20A93718278>

# %%
canvas.style_image
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x20A937A6F98>

# %% [markdown]
# ## Random Noise

# %%
canvas.random_noise_image
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x20A939173C8>

# %% [markdown]
# # A Neural Algorithm of Artistic Style

# %%
alg = NeuralAlgorithmOfArtisticStyle(content_weight=5, style_weight=100, variation_weight=2, is_notebook=True)
# alg = NeuralAlgorithmOfArtisticStyle(is_notebook=True)
alg
# Out:
# NeuralAlgorithmOfArtisticStyle(content_weight='5', style_weight='100', variation_weight='2', content_layer=block4_conv2, style_layers=['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1'], is_notebook=True)

# %%
alg(canvas, iterations=10)
