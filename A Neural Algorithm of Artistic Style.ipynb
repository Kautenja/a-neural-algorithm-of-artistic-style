# %%
# reproducable randomness
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\users\ck\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from neural_stylization.neural_alg_of_artistic_style import Canvas, NeuralAlgorithmOfArtisticStyle
# Out:
# Using TensorFlow backend.

# %%
canvas = Canvas(content_path='img/content/tubingen.jpg',
                style_path='img/styles/starry_night_google.jpg',
                dimensions=(600, 400))
canvas
# Out:
# Canvas(content_path='img/content/tubingen.jpg', style_path='img/styles/starry_night_google.jpg', dimensions=(600, 400))

# %%
canvas.content_image
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1863CBD8D68>

# %%
canvas.style_image
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1863CC6B668>

# %% [markdown]
# ## Random Noise

# %%
canvas.random_noise_image
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1863D2639E8>

# %% [markdown]
# # A Neural Algorithm of Artistic Style

# %%
alg = NeuralAlgorithmOfArtisticStyle(content_weight=5, style_weight=100, variation_weight=1e4, is_notebook=True)
# alg = NeuralAlgorithmOfArtisticStyle(is_notebook=True)
alg
# Out:
# NeuralAlgorithmOfArtisticStyle(
#     content_weight=5,
#     style_weight=100,
#     variation_weight=10000.0,
#     content_layer='block4_conv2',
#     style_layers=['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1'],
#     is_notebook=True
# )

# %%
alg(canvas, iterations=25)
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1863F045FD0>
