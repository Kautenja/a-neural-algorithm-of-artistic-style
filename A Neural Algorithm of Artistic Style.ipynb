# %%
# reproducable randomness
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from neural_stylization.neural_alg_of_artistic_style import Canvas, NeuralAlgorithmOfArtisticStyle
# Out:
# Using TensorFlow backend.

# %%
canvas = Canvas(content_path='img/content/tubingen.jpg',
                style_path='img/styles/seated-nude.jpg',
                dimensions=(300, 200))
canvas
# Out:
# Canvas(content_path='img/content/tubingen.jpg', style_path='img/styles/seated-nude.jpg', dimensions=(300, 200))

# %%
canvas.content_image
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1126B3668>

# %%
canvas.style_image
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x11272B8D0>

# %% [markdown]
# ## Random Noise

# %%
canvas.random_noise_image
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x112CAA7F0>

# %% [markdown]
# # A Neural Algorithm of Artistic Style

# %%
alg = NeuralAlgorithmOfArtisticStyle(content_weight=5, style_weight=100, variation_weight=1e4, is_notebook=True)
# alg = NeuralAlgorithmOfArtisticStyle(is_notebook=True)
alg
# Out:
# NeuralAlgorithmOfArtisticStyle(
#     content_weight=5,
#     style_weight=100,
#     variation_weight=10000.0,
#     content_layer='block4_conv2',
#     style_layers=['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1'],
#     is_notebook=True
# )

# %%
alg(canvas, iterations=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ff2afa0e894a> in <module>()
# ----> 1 alg(canvas, iterations=2)
#
# ~/Dropbox/PhD/coursework/02 - Spring 2018/COMP7970 - Deep Learning/Presentation/neural_stylization/neural_alg_of_artistic_style.py in __call__(self, canvas, iterations)
#     159
#     160         for step in range(iterations):
# --> 161             sess.run([train_op, loss], feed_dict={canvas.output: x})
#     162         # # define the gradients of the loss function and the canvas output
#     163         # grads = backend.gradients(loss, canvas.output)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1087             feed_handles[subfeed_t] = subfeed_val
#    1088           else:
# -> 1089             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1090
#    1091           if (not is_tensor_handle_feed and
#
# /usr/local/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: setting an array element with a sequence.
